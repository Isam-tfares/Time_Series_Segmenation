# %%
import pandas as pd

# %% [markdown]
# <h3>TSSB dataset</h3>

# %%
pd.read_csv("TSSB.csv")
# Out:
#                  name_algo  Covering  F-measure  NAB (Standard)  NAB (LowFP)  \
# 0  BinaryClaSPSegmentation  0.854771   0.895600       49.383043    43.308116
# 1       DynamicProgramming  0.467855   1.000000       29.161884    23.325362
# 2                    FLOSS  0.519369   0.514652       51.015072    19.708116
# 3                     Pelt  0.375945   0.483418        2.687681    -2.940290
# 4                     BOCD  0.545541   1.000000       27.403478    21.974638
# 5                    Fluss  0.666155   0.795333       40.277681    34.569420
# 6             Vanilla_LSTM  0.375934   0.415793      -28.566957  -104.512174
#
#    NAB (LowFN)
# 0    51.572609
# 1    32.527536
# 2    61.466522
# 3     4.690580
# 4    29.386667
# 5    42.380145
# 6    -3.243623

# %%
pd.read_csv("TSSB.csv")['name_algo'].values
# Out:
# array(['BinaryClaSPSegmentation', 'DynamicProgramming', 'FLOSS', 'Pelt',
#        'BOCD', 'Fluss', 'Vanilla_LSTM'], dtype=object)

# %% [markdown]
# <h3>SKAB dataset</h3>

# %%
pd.read_csv("SKAB.csv")
# Out:
#                  name_algo  Covering  F-measure  NAB (Standard)  NAB (LowFP)  \
# 0  BinaryClaSPSegmentation  0.465255   0.442647        7.507647     6.928824
# 1       DynamicProgramming  0.583857   0.975490       49.632647    43.755294
# 2                    FLOSS  0.583853   0.864597       50.882941    45.155294
# 3                     Pelt  0.363974   0.349020        0.000000     0.000000
# 4                     BOCD  0.513603   0.990196       54.106471    48.756765
# 5                    Fluss  0.536557   0.784851       32.614118    28.003529
#
#    NAB (LowFN)
# 0     7.701471
# 1    51.632941
# 2    53.042059
# 3     0.000000
# 4    56.003824
# 5    34.326176

# %% [markdown]
# <h3>TCPD dataset</h3>

# %%
pd.read_csv("TCPD.csv")
# Out:
#                  name_algo  Covering  F-measure  NAB (Standard)  NAB (LowFP)  \
# 0  BinaryClaSPSegmentation  0.396290   0.353410        1.730000     1.653636
# 1       DynamicProgramming  0.648170   1.000000       79.253636    74.259545
# 2                    FLOSS  0.380498   0.361795        5.997273     5.459091
# 3                     Pelt  0.410525   0.485473       39.994545    -7.898636
# 4                     BOCD  0.473227   0.801091       46.473636    43.880909
# 5                    Fluss  0.393466   0.338157       -0.253182    -1.511818
#
#    NAB (LowFN)
# 0     1.759545
# 1    81.005909
# 2     6.185455
# 3    56.019091
# 4    47.585455
# 5     0.201364

# %% [markdown]
# <h3>Human activity dataset</h3>

# %%
pd.read_csv("results_human_activity_segmentation.csv")
# Out:
#                  name_algo  Covering  F-measure  NAB (Standard)  NAB (LowFP)  \
# 0  BinaryClaSPSegmentation  0.612520   0.721318       40.931127    36.440986
# 1       DynamicProgramming  0.833212   1.000000       77.612045    71.894773
# 2                    Fluss  0.647730   0.993981       43.828402    38.870548
# 3                     BOCD  0.475852   1.000000       45.196000    39.700000
# 4                     Pelt  0.359934   0.241845      -13.612466  -123.925845
# 5                    FLOSS  0.491787   0.490793       48.998402    15.566347
#
#    NAB (LowFN)
# 0    42.537324
# 1    79.818864
# 2    45.602968
# 3    47.297000
# 4    23.178676
# 5    60.194247

# %% [markdown]
# <h3>MOSAD dataset</h3>

# %%
pd.read_csv("MOSAD.csv")
# Out:
#                  name_algo  Covering  F-measure  NAB (Standard)  NAB (LowFP)  \
# 0                     BOCD  0.502056   0.947822       43.294896    38.578078
# 1  BinaryClaSPSegmentation  0.582209   0.603244       24.887954    22.082890
# 2       DynamicProgramming  0.633273   0.993873       58.915053    53.308744
# 3                    FLOSS  0.493877   0.557959       39.223422    21.472212
# 4                    Fluss  0.560977   0.728080       29.116755    24.982920
# 5                     Pelt  0.377594   0.389939        7.267440   -33.691193
# 6             Vanilla_LSTM  0.425635   0.439041        1.632139   -20.517869
#
#    NAB (LowFN)
# 0    45.068236
# 1    25.892737
# 2    61.246313
# 3    45.222070
# 4    30.627663
# 5    20.972087
# 6     9.076504
